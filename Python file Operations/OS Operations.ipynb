# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\SatishMoparthi\\Downloads\\Python'

# %%
# Few os commands
    # os.chdir() --> Child directory 
    # os.rename()
    # os.remove()
    # os.mkdir()
    # os.rmdir()  --> To delete folder, we need to delete the file in folder

# %%
import os
st = 'C:\\Users\\SatishMoparthi\\Downloads\\Python'
for f in os.listdir(st):
    print(f)
# Out:
# .ipynb_checkpoints
# AI_Movies.txt
# OOP_FILE_OS_SHUTIL.ipynb
# Operations on files using Python.ipynb
# OS Operations.ipynb
# Python for AI
# Python for ML_AI.ipynb
# Python.txt
# Python_text.txt

# %%
import os
st = 'C:\\Users\\SatishMoparthi\\Downloads\\Python'
for f in os.listdir(st):
    print("Filename ", f, 'filesize is ',os.path.getsize(f))
# Out:
# Filename  .ipynb_checkpoints filesize is  4096
# Filename  AI_Movies.txt filesize is  218
# Filename  OOP_FILE_OS_SHUTIL.ipynb filesize is  27364
# Filename  Operations on files using Python.ipynb filesize is  5988
# Filename  OS Operations.ipynb filesize is  5046
# Filename  Python for AI filesize is  4096
# Filename  Python for ML_AI.ipynb filesize is  70116
# Filename  Python.txt filesize is  233
# Filename  Python_text.txt filesize is  471

# %%
# os.path.exist(path) --> Returns TRUE or FALSE
# os.path.isdir(directory name) --> Return TRUE or FALSE

# %%
# Copy files and folders

import shutil
shutil.copy('C:\\Users\\SatishMoparthi\\Downloads\\Python\\Python_text.txt','C:\\Users\\SatishMoparthi\\Downloads\\')
# Out:
# 'C:\\Users\\SatishMoparthi\\Downloads\\Python_text.txt'

# %%
# Shutil.copytree is used to copy folder 

import os
os.chdir('C:\\Satish')
for f in os.listdir():
    if f.endswith('.txt'):
        os.unlink(f)  
#unlink() method in Python is used to remove or delete a file path. This method is semantically identical to os.

# %%
#wlak --> Every file in folder , subfolder is a given path

import os
for fold,sfs,fns in os.walk('C:\\Users\\SatishMoparthi\\Downloads'):
    print("Current folder name",fold)
    for sf in sfs:
        print(sf)
    for fn in fns:
        print(fn)
# Out:
# Current folder name C:\Users\SatishMoparthi\Downloads
# Applied AI Course Live
# Capgemini ML
# Documents
# E-books_PPT_ML_AI
# IBL_Your_Learning
# Ipython
# Machine Learning A-Z New
# Manipal
# novel-corona-virus-2019-dataset
# Python
# desktop.ini
# DSC_0070.jpg
# Python_text.txt
# Current folder name C:\Users\SatishMoparthi\Downloads\Applied AI Course Live
# .ipynb_checkpoints
# LIVE-1_Python.ipynb
# LIVE-1_Python.txt
# LIVE_2_Mathematical_Programming_Problems.ipynb
# LIVE_2_Mathematical_Programming_Problems.pdf
# LIVE_3_More_Math_Programming_Problems.ipynb
# LIVE_3_More_Math_Programming_Problems.pdf
# LIVE_4_Strings_Regex.ipynb
# LIVE_4_Strings_Regex.pdf
# LIVE_5_Strings_Regexes_II.ipynb
# LIVE_5_Strings_Regexes_II.pdf
# LIVE_6_DP_inbuilt_DS.ipynb
# LIVE_6_DP_inbuilt_DS.pdf
# LIVE_OOP_Basics_II.ipynb
# LIVE_OOP_Basics_II.pdf
# LIVE_OOP_Basics_Python_I.ipynb
# LIVE_OOP_Basics_Python_I.pdf
# ...
